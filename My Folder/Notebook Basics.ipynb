# %%
print("Hello World")

# %%
# %sql
select "Hello world from sql!"

# %% [markdown]
# # Title 1
# ## Title 2
# ### Title 3
#
# **Bold text**
#
# *Italic text*
#
# > Blockquote
#
# - Bullet point 1
# - Bullet point 2
#
# 1. Numbered item 1
# 2. Numbered item 2
#
# `Inline code`

# %%
# %run ./Includes/setup

# %%
print(full_name)

# %%
# %fs ls '/databricks-datasets'

# %%
dbutils.help()

# %%
dbutils.fs.help()

# %%
files=dbutils.fs.ls ('/databricks-datasets')
print(files)

# %%
display(files)
